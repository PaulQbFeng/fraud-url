# %%
import shutil
import numpy as np
import pandas as pd
import tensorflow as tf
print(tf.__version__)
# Out:
# 1.8.0

# %% [markdown]
# ### Load data and preprocessing

# %%
train_df = pd.read_csv('./train.csv', sep=',')
eval_df = pd.read_csv('./eval.csv', sep=',')
test_df = pd.read_csv('./test.csv', sep=',')

# %%
train_df = train_df.drop(['poweredBy', 'serverType', 'lastModified', 'contentType'], axis=1)
eval_df = eval_df.drop(['poweredBy', 'serverType', 'lastModified', 'contentType'], axis=1)
test_df = test_df.drop(['poweredBy', 'serverType', 'lastModified', 'contentType'], axis=1)

# %%
train_df.head()
# Out:
#                                                  url compromissionType  \
# 0  9d345009-a-62cb3a1a-s-sites.googlegroups.com/s...          phishing
# 1                 ok.aaweb.asia/m=weblogin/index.htm          phishing
# 2                          www.smalbro.dk/sejeal.jpg        defacement
# 3                              bjgdhm.com/index.html        defacement
# 4                              commsure.in/index.php          phishing
#
#    isHiddenFraudulent  contentLength
# 0                True              0
# 1                True          23060
# 2                True         104772
# 3               False           1463
# 4               False              0

# %%
def add_more_features(dataframe):
    df = dataframe.copy()
    df['url_length'] = df['url'].apply(lambda x:len(x))    
    return df

# %%
# Create pandas input function
def make_train_input_fn(df, batch_size, num_epochs):
    return tf.estimator.inputs.pandas_input_fn(
        x = add_more_features(df),
        y = df['isHiddenFraudulent'],
        batch_size = batch_size,
        num_epochs = num_epochs,
        shuffle = True,
        queue_capacity = 1024,
        num_threads = 1
    )

# %%
def make_eval_input_fn(df, batch_size):
    return tf.estimator.inputs.pandas_input_fn(
        x = add_more_features(df),
        y = df['isHiddenFraudulent'], 
        batch_size = 256,
        num_epochs = 1,
        shuffle = False,
        queue_capacity = 1024,
        num_threads = 1
    )

# %%
def make_test_input_fn(df):
    return tf.estimator.inputs.pandas_input_fn(
        x = add_more_features(df),
        batch_size = 16,
        num_epochs = 1,
        shuffle = False,
        queue_capacity = 1024,
        num_threads = 1
    )

# %%
def create_feature_cols():
    cols = [tf.feature_column.numeric_column('url_length'),
           tf.feature_column.numeric_column('contentLength')]
    #try bucketize url_length 5 
    return cols 

feature_cols = create_feature_cols()

# %%
def serving_input_fn():
    
    json_feature_placeholders = {
        'url_length': tf.placeholder(tf.int64, [None]),
        'contentLength': tf.placeholder(tf.int64, [None])
    }
    features = json_feature_placeholders
    
    return tf.estimator.export.ServingInputReceiver(features, json_feature_placeholders)

# %%
# def serving_input_fn():
    
#     def get_length(single_string):
#         x = tf.expand_dims(single_string,0)
#         splitted = tf.string_split(x, delimiter="").values
#         length = tf.size(splitted)
#         return length

#     def get_lengths(string_batch):
#         return tf.map_fn(get_length, string_batch, dtype=tf.int32)
    
#     json_feature_placeholders = {
#         'url': tf.placeholder(tf.string, None),
#     }
    
#     features = {
#         'url_length': get_lengths(json_feature_placeholders['url'])
#     }    

#     return tf.estimator.export.ServingInputReceiver(features, json_feature_placeholders)

# %% [markdown]
# ### Each model function

# %%
# Create estimator train and evaluate function
NUM_EPOCH = 10
BATCH_SIZE = 256
SAVE_CKPT_STEPS = 200 # steps
EVAL_INTERVAL_SEC =  5 # sec
HIDDEN_UNITS = [32,8,2]
MAX_STEPS = train_df.shape[0]//BATCH_SIZE * NUM_EPOCH

def train_and_evaluate(output_dir, model='linear'):
    
    run_config = tf.estimator.RunConfig(model_dir=output_dir, 
                                        save_summary_steps=50,
                                        keep_checkpoint_max=10,
                                        save_checkpoints_steps=SAVE_CKPT_STEPS)
    
    if model == 'linear':
        estimator = tf.estimator.LinearClassifier(feature_columns=feature_cols, 
                                               config=run_config)
    else:
        estimator = tf.estimator.DNNClassifier(feature_columns=feature_cols, hidden_units=HIDDEN_UNITS,
                                           config=run_config)

    train_spec = tf.estimator.TrainSpec(input_fn=make_train_input_fn(train_df, BATCH_SIZE, NUM_EPOCH), 
                                        max_steps=MAX_STEPS)

    export_latest = tf.estimator.LatestExporter(name='exporter', 
                                                serving_input_receiver_fn=serving_input_fn,
                                                exports_to_keep=None)

    eval_spec = tf.estimator.EvalSpec(input_fn=make_eval_input_fn(eval_df, BATCH_SIZE), 
                                    steps=None,
                                    start_delay_secs = 1, # start evaluating after N seconds
                                    throttle_secs = EVAL_INTERVAL_SEC,     # evaluate every N seconds
                                    exporters=export_latest
                                    )

    tf.estimator.train_and_evaluate(estimator, train_spec, eval_spec)
    
    return estimator

# %%
outdir = '../trained_model/url_len_contlen_linear/'

# %%
shutil.rmtree(outdir, ignore_errors = True)
estimator = train_and_evaluate(outdir, model='linear')
# Out:
# INFO:tensorflow:Using config: {'_model_dir': '../trained_model/url_len_contlen_linear/', '_tf_random_seed': None, '_save_summary_steps': 50, '_save_checkpoints_steps': 200, '_save_checkpoints_secs': None, '_session_config': None, '_keep_checkpoint_max': 10, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x122f2cb00>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after 5 secs (eval_spec.throttle_secs) or training is finished.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into ../trained_model/url_len_contlen_linear/model.ckpt.
# INFO:tensorflow:loss = 177.44576, step = 1
# INFO:tensorflow:global_step/sec: 220.741
# INFO:tensorflow:loss = 2021.3347, step = 101 (0.455 sec)
# INFO:tensorflow:Saving checkpoints for 201 into ../trained_model/url_len_contlen_linear/model.ckpt.
# INFO:tensorflow:global_step/sec: 334.55
# INFO:tensorflow:loss = 7829.6245, step = 201 (0.298 sec)
# INFO:tensorflow:global_step/sec: 400.046
# INFO:tensorflow:loss = 528.4717, step = 301 (0.250 sec)
# INFO:tensorflow:Saving checkpoints for 401 into ../trained_model/url_len_contlen_linear/model.ckpt.
# INFO:tensorflow:global_step/sec: 285.602
# INFO:tensorflow:loss = 7682.7407, step = 401 (0.350 sec)
# INFO:tensorflow:global_step/sec: 383.198
# INFO:tensorflow:loss = 4079.6982, step = 501 (0.262 sec)
# INFO:tensorflow:Saving checkpoints for 601 into ../trained_model/url_len_contlen_linear/model.ckpt.
# INFO:tensorflow:global_step/sec: 338.61
# INFO:tensorflow:loss = 1822.6572, step = 601 (0.294 sec)
# INFO:tensorflow:global_step/sec: 393.335
# INFO:tensorflow:loss = 256.62012, step = 701 (0.256 sec)
# INFO:tensorflow:Saving checkpoints for 801 into ../trained_model/url_len_contlen_linear/model.ckpt.
# INFO:tensorflow:global_step/sec: 328.55
# INFO:tensorflow:loss = 3838.67, step = 801 (0.302 sec)
# INFO:tensorflow:global_step/sec: 372.149
# INFO:tensorflow:loss = 396.20996, step = 901 (0.271 sec)
# INFO:tensorflow:Saving checkpoints for 1001 into ../trained_model/url_len_contlen_linear/model.ckpt.
# INFO:tensorflow:global_step/sec: 312.578
# INFO:tensorflow:loss = 3352.3066, step = 1001 (0.317 sec)
# INFO:tensorflow:global_step/sec: 373.533
# INFO:tensorflow:loss = 2924.698, step = 1101 (0.270 sec)
# INFO:tensorflow:Saving checkpoints for 1201 into ../trained_model/url_len_contlen_linear/model.ckpt.
# INFO:tensorflow:global_step/sec:
into ../trained_model/url_len_contlen_linear/model.ckpt.
# INFO:tensorflow:Loss for final step: 838.9592.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-03-12-23:07:26
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../trained_model/url_len_contlen_linear/model.ckpt-4685
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-03-12-23:07:27
# INFO:tensorflow:Saving dict for global step 4685: accuracy = 0.73154205, accuracy_baseline = 0.5037596, auc = 0.66631764, auc_precision_recall = 0.73397267, average_loss = 2.8445978, global_step = 4685, label/mean = 0.4962404, loss = 724.48004, precision = 0.80734074, prediction/mean = 0.5181552, recall = 0.60288566
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Classification input must be a single string Tensor; got {'url_length': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=int64>, 'contentLength': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=int64>}
# INFO:tensorflow:'classification' : Classification input must be a single string Tensor; got {'url_length': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=int64>, 'contentLength': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=int64>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'url_length': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=int64>, 'contentLength': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=int64>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from ../trained_model/url_len_contlen_linear/model.ckpt-4685
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: b"../trained_model/url_len_contlen_linear/export/exporter/temp-b'1552432047'/saved_model.pb"
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../trained_model/url_len_contlen_linear/model.ckpt-4685
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 4686 into ../trained_model/url_len_contlen_linear/model.ckpt.
# INFO:tensorflow:loss = 945.50653, step = 4686
# INFO:tensorflow:global_step/sec: 220.994
# INFO:tensorflow:loss = 369.11615, step = 4786 (0.455 sec)
# INFO:tensorflow:Saving checkpoints for 4886 into ../trained_model/url_len_contlen_linear/model.ckpt.
# INFO:tensorflow:global_step/sec: 330.58
# INFO:tensorflow:loss = 742.90857, step = 4886 (0.301 sec)
# INFO:tensorflow:global_step/sec: 409.165
# INFO:tensorflow:loss = 2925.8691, step = 4986 (0.246 sec)
# INFO:tensorflow:Saving checkpoints for 5086 into ../trained_model/url_len_contlen_linear/model.ckpt.
# INFO:tensorflow:global_step/sec: 330.314
# INFO:tensorflow:loss = 2741.4287, step = 5086 (0.301 sec)
# INFO:tensorflow:global_step/sec: 403.972
# INFO:tensorflow:loss = 587.6905, step = 5186 (0.247 sec)
# INFO:tensorflow:Saving checkpoints for 5286 into ../trained_model/url_len_contlen_linear/model.ckpt.
# INFO:tensorflow:global_step/sec: 340.833
# INFO:tensorflow:loss = 892.81195, step = 5286 (0.294 sec)
# INFO:tensorflow:global_step/sec: 383.973
# INFO:tensorflow:loss = 1503.9971, step = 5386 (0.262 sec)
# INFO:tensorflow:Saving checkpoints for 5486 into ../trained_model/url_len_contlen_linear/model.ckpt.
# INFO:tensorflow:global_step/sec: 352.45
# INFO:tensorflow:loss = 1426.03, step = 5486 (0.282 sec)
# INFO:tensorflow:global_step/sec: 399.599
# INFO:tensorflow:loss = 477.1447, step = 5586 (0.251 sec)
# INFO:tensorflow:Saving checkpoints for 5686 into ../trained_model/url_len_contlen_linear/model.ckpt.
# INFO:tensorflow:global_step/sec: 304.486
# INFO:tensorflow:loss = 1288.3451, step = 5686 (0.327 sec)
# INFO:tensorflow:global_step/sec: 361.533
# INFO:tensorflow:loss = 2415.044, step = 5786 (0.278 sec)
# INFO:tensorflow:Saving checkpoints for 5886 into ../trained_model/url_len_contlen_linear/model.ckpt.
# INFO:tensorflow:global_step/sec: 348.144
# INFO:tensorflow:loss = 898.6248, step = 5886 (0.286 sec)
# INFO:tensorflow:global_step/sec: 401.025
# INFO:tensorflow:loss = 1389.6273, step = 5986 (0.251 sec)
# INFO:tensorflow:Saving checkpoints for 6086 into ../trained_model/url_len_contlen_linear/model.ckpt.
# INFO:tensorflow:global_step/sec: 326.134
# INFO:tensorflow:loss = 941.16425, step = 6086 (0.305 sec)
# INFO:tensorflow:global_step/sec: 399.821
# INFO:tensorflow:loss = 1389.9746, step = 6186 (0.252 sec)
# INFO:tensorflow:Saving checkpoints for 6247 into ../trained_model/url_len_contlen_linear/model.ckpt.
# INFO:tensorflow:Loss for final step: 475.9475.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-03-12-23:07:33
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../trained_model/url_len_contlen_linear/model.ckpt-6247
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-03-12-23:07:34
# INFO:tensorflow:Saving dict for global step 6247: accuracy = 0.5876511, accuracy_baseline = 0.5037596, auc = 0.36849502, auc_precision_recall = 0.5381084, average_loss = 2.7480617, global_step = 6247, label/mean = 0.4962404, loss = 699.8936, precision = 0.87291807, prediction/mean = 0.2852402, recall = 0.19785903
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Classification input must be a single string Tensor; got {'url_length': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=int64>, 'contentLength': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=int64>}
# INFO:tensorflow:'classification' : Classification input must be a single string Tensor; got {'url_length': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=int64>, 'contentLength': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=int64>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'url_length': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=int64>, 'contentLength': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=int64>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from ../trained_model/url_len_contlen_linear/model.ckpt-6247
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: b"../trained_model/url_len_contlen_linear/export/exporter/temp-b'1552432054'/saved_model.pb"
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../trained_model/url_len_contlen_linear/model.ckpt-6247
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 6248 into ../trained_model/url_len_contlen_linear/model.ckpt.
# INFO:tensorflow:loss = 717.3683, step = 6248
# INFO:tensorflow:global_step/sec: 241.926
# INFO:tensorflow:loss = 2061.7373, step = 6348 (0.415 sec)
# INFO:tensorflow:Saving checkpoints for 6448 into ../trained_model/url_len_contlen_linear/model.ckpt.
# INFO:tensorflow:global_step/sec: 336.164
# INFO:tensorflow:loss = 2322.8518, step = 6448 (0.296 sec)
# INFO:tensorflow:global_step/sec: 402.957
# INFO:tensorflow:loss = 2121.315, step = 6548 (0.249 sec)
# INFO:tensorflow:Saving checkpoints for 6648 into ../trained_model/url_len_contlen_linear/model.ckpt.
# INFO:tensorflow:global_step/sec: 330.688
# INFO:tensorflow:loss = 1090.3778, step = 6648 (0.302 sec)
# INFO:tensorflow:global_step/sec: 378.089
# INFO:tensorflow:loss = 1882.7706, step = 6748 (0.266 sec)
# INFO:tensorflow:Saving checkpoints for 6848 into ../trained_model/url_len_contlen_linear/model.ckpt.
# INFO:tensorflow:global_step/sec: 347.213
# INFO:tensorflow:loss = 932.46027, step = 6848 (0.287 sec)
# INFO:tensorflow:global_step/sec: 346.134
# INFO:tensorflow:loss = 1266.1973, step = 6948 (0.291 sec)
# INFO:tensorflow:Saving checkpoints for 7048 into ../trained_model/url_len_contlen_linear/model.ckpt.
# INFO:tensorflow:global_step/sec: 342.201
# INFO:tensorflow:loss = 593.25494, step = 7048 (0.290 sec)
# INFO:tensorflow:Saving checkpoints for 7120 into ../trained_model/url_len_contlen_linear/model.ckpt.
# INFO:tensorflow:Loss for final step: 345.81427.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-03-12-23:07:38
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../trained_model/url_len_contlen_linear/model.ckpt-7120
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-03-12-23:07:39
# INFO:tensorflow:Saving dict for global step 7120: accuracy = 0.58505917, accuracy_baseline = 0.5037596, auc = 0.36665583, auc_precision_recall = 0.5364986, average_loss = 4.1724224, global_step = 7120, label/mean = 0.4962404, loss = 1062.6587, precision = 0.8446475, prediction/mean = 0.28818718, recall = 0.20075503
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Signatures EXCLUDED from export because they cannot be be served via TensorFlow Serving APIs:
# INFO:tensorflow:'serving_default' : Classification input must be a single string Tensor; got {'url_length': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=int64>, 'contentLength': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=int64>}
# INFO:tensorflow:'classification' : Classification input must be a single string Tensor; got {'url_length': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=int64>, 'contentLength': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=int64>}
# INFO:tensorflow:'regression' : Regression input must be a single string Tensor; got {'url_length': <tf.Tensor 'Placeholder:0' shape=(?,) dtype=int64>, 'contentLength': <tf.Tensor 'Placeholder_1:0' shape=(?,) dtype=int64>}
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:Restoring parameters from ../trained_model/url_len_contlen_linear/model.ckpt-7120
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: b"../trained_model/url_len_contlen_linear/export/exporter/temp-b'1552432059'/saved_model.pb"

# %% [markdown]
# ### Serving

# %%
url_ex = "https://github.com/warmspringwinds/tf-image-segmentation/issues/10"
len(url_ex)
# Out:
# 66

# %%
# %%writefile url.json
# {"url_lenght": 66}
# Out:
# Overwriting url.json

# %%
# %%bash
#
# location=/Users/paul/Desktop/Google_ASL/trained_model/url_len_dnn/export/exporter/1552430670
# gcloud ml-engine local predict --model-dir=$location --json-instances=url.json --verbosity debug

# %% [markdown]
# #### Load models

# %%
import tensorflow as tf

output_dir = '../trained_model/url_len_linear/'

def create_feature_cols():
    cols = [tf.feature_column.numeric_column('url_length')]
    #try bucketize url_length 5 
    return cols 

feature_cols = create_feature_cols()

run_config = tf.estimator.RunConfig(model_dir=output_dir, 
                                  keep_checkpoint_max=10,
                                  save_summary_steps=100, 
                                  save_checkpoints_steps=200)

estimator = tf.estimator.LinearClassifier(feature_columns=feature_cols, 
                                       config=run_config)
# Out:
# INFO:tensorflow:Using config: {'_model_dir': '../trained_model/url_len_linear/', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': 200, '_save_checkpoints_secs': None, '_session_config': None, '_keep_checkpoint_max': 10, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x12e068860>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
predictions = estimator.predict(input_fn=make_test_input_fn(test_df))

# %%
list(predictions)[:20]
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../trained_model/url_len_linear/model.ckpt-7000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# [{'logits': array([0.9270397], dtype=float32),
#   'logistic': array([0.7164743], dtype=float32),
#   'probabilities': array([0.28352568, 0.7164743 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.37803602], dtype=float32),
#   'logistic': array([0.40660068], dtype=float32),
#   'probabilities': array([0.59339935, 0.40660068], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.09155598], dtype=float32),
#   'logistic': array([0.477127], dtype=float32),
#   'probabilities': array([0.52287304, 0.477127  ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.20296489], dtype=float32),
#   'logistic': array([0.44943225], dtype=float32),
#   'probabilities': array([0.55056775, 0.44943225], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.9270397], dtype=float32),
#   'logistic': array([0.7164743], dtype=float32),
#   'probabilities': array([0.28352568, 0.7164743 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.163176], dtype=float32),
#   'logistic': array([0.45929632], dtype=float32),
#   'probabilities': array([0.5407037 , 0.45929626], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([1.0265119], dtype=float32),
#   'logistic': array([0.7362391], dtype=float32),
#   'probabilities': array([0.2637609, 0.7362391], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.3143738], dtype=float32),
#   'logistic': array([0.42204753], dtype=float32),
#   'probabilities': array([0.5779525, 0.4220475], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.24275379], dtype=float32),
#   'logistic': array([0.43960783], dtype=float32),
#   'probabilities': array([0.5603922 , 0.43960783], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([1.0265119], dtype=float32),
#   'logistic': array([0.7362391], dtype=float32),
#   'probabilities': array([0.2637609, 0.7362391], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.26264822], dtype=float32),
#   'logistic': array([0.43471283], dtype=float32),
#   'probabilities': array([0.5652872, 0.4347128], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.19500712], dtype=float32),
#   'logistic': array([0.45140213], dtype=float32),
#   'probabilities': array([0.5485979, 0.4514021], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.29845822], dtype=float32),
#   'logistic': array([0.4259344], dtype=float32),
#   'probabilities': array([0.57406557, 0.4259344 ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.28254268], dtype=float32),
#   'logistic': array([0.4298305], dtype=float32),
#   'probabilities': array([0.57016945, 0.4298305 ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.13524073], dtype=float32),
#   'logistic': array([0.53375876], dtype=float32),
#   'probabilities': array([0.46624127, 0.53375876], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.3462049], dtype=float32),
#   'logistic': array([0.41430303], dtype=float32),
#   'probabilities': array([0.585697  , 0.41430303], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.07166153], dtype=float32),
#   'logistic': array([0.48209226], dtype=float32),
#   'probabilities': array([0.5179077 , 0.48209226], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.32233158], dtype=float32),
#   'logistic': array([0.4201076], dtype=float32),
#   'probabilities': array([0.57989234, 0.4201076 ], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.32631046], dtype=float32),
#   'logistic': array([0.4191386], dtype=float32),
#   'probabilities': array([0.5808614, 0.4191386], dtype=float32),
#   'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.9270397], dtype=float32),
#   'logistic': array([0.7164743], dtype=float32),
#   'probabilities': array([0.28352568, 0.7164743 ], dtype=float32),
#   'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object)}]

# %%
'1'.isalnum()
# Out:
# True
